# %%
import pandas as pd

# %%
# Out:
# (7799, 18)

# %%
df = pd.read_csv("Arena_QS_updated.csv")

# %%
df.shape
# Out:
# (7799, 17)

# %%
df['text_len'] = df['text'].apply(lambda x: len(x))

# %%
df = df[df.text_len < 50_000]

# %%
df.shape
# Out:
# (5925, 18)

# %%
df.to_csv("Arena_QS_updated_filtered.csv", index=False)

# %%
df.text_len.hist(bins=100, figsize=(20,10))
# Out:
# <Axes: >
